# %% [markdown]
# # 전화번호 프로그램 만들기
#
# * 홍길동 010-123-4567
# * 기능1 : 연락처 추가
# * 기능2 : 연락처 전체 보기
# * 기능3 : 검색, 이름을 입력받아서 전화번호 조회
# * 기능4 : 수정, 이름을 입력받아서 전화번호 입력수정
# * 기능5 : 삭제, 이름 입력받아서 삭제
# * 기능6 : 프로그램 종료

# %%
# 1. 최초에 총합 6개의 기능이 있는 (while)화면 출력
# 2. (1)번 선택시 번호를 받고 받은 번호는 리스트에 저장
# 3. (2)번 선택시 리스트의 모든 번호를 출력
# 4. (3)번 선택시 
# 5. (4)번 선택시 리플레이스를 통해 자료형값 수정
# 6. (5)번 선택시 del을 통해 자료형 값 삭제
# 7. (6)번 선택시 브레이크


 # 기능 영역

while True:
    print('전화번호 프로그램 기능 목록')
    print('1. 연락처 추가')
    print('2. 연락저 전체 보기')
    print('3. 검색')
    print('4. 수정 ')
    print('5. 삭제')
    print('6. 프로그램 종료')

# 기능 선택 영역
    select = input("기능을 선택해주세요 : ")

# 번호별 기능 영역
    
    if select == '1' : # 연락처 추가
        name = input('이름을 입력하세요 : ')
        phone = input('전화번호를 입력하세요 : ')
        contact[name] = number
        print ('번호가 추가되었습니다. ')
        
    elif select == '2': # 연락처 전체보기
        print('   연락처 전체보기   ')
            for name, number in contact.items();
        if not contact
            print('등록된 연락처가 없습니다.')
         else:
            for name, number in contact.items():
                print(f"{name}: {number}")

    elif select == '3': #검색
        name = input('검색할 이름을 입력해주세요 : ')
        if name in contact:
            print(f'{name}의 전화번호는 {contact[name]}입니다. ')
        else:
            print('등록되지 않는 번호입니다.')
            
    elif choice == '4': #수정
        name = input('수정할 이름을 입력해주세요 : ')
        if name in contact
            number2=input('변경된 번호를 입력해주세요 : ')
            contact[name] = number2
            print('수정이 완료 되었습니다.')
        else:
            print("조회할 수 없는 이름입니다. ")

    elif choice == '5':  # 삭제
        name = input("삭제할 이름을 입력하세요: ")
        if name in contact:
            del contact[name]
            print("연락처가 삭제되었습니다.")
        else:
            print("연락처에 등록되어 있지 않습니다.")


    elif choice == '6':  # 프로그램 종료
        print("프로그램을 종료합니다.")
        break

    else: # 1 to 6 외의 번호 입력
        print("다시 선택해주세요.")

# %% [markdown]
# 전화번호 프로그램 만들기
# 홍길동 010-123-4567
# 기능1 : 연락처 추가
# 기능2 : 연락처 전체 보기
# 기능3 : 검색, 이름을 입력받아서 전화번호 조회
# 기능4 : 수정, 이름을 입력받아서 전화번호 입력수정
# 기능5 : 삭제, 이름 입력받아서 삭제
# 기능6 : 프로그램 종료

# %%
contact = {}

while True:
    print('전화번호 프로그램 기능 목록')
    print('1. 연락처 추가')
    print('2. 연락저 전체 보기')
    print('3. 검색')
    print('4. 수정 ')
    print('5. 삭제')
    print('6. 프로그램 종료')
    
    menu = int(input('메뉴를 선택해 주세요(1~6): '))
    
    if menu == 1:
        print('연락처를 추가합니다.')
        new_name = input('이름 : ')
        new_tel = input('전화번호 : ')
        print(new_name, new_tel)
        contact.setdefault(new_name, new_tel)

        
    elif menu == 2:
        print('연락처를 조회합니다.')
        for name, tel in contact.items():
            print(name, ":", tel)
        
    elif menu == 3:
        print('연락처를 검색합니다.')
        search_name = input('이름 : ')
        print(contact.get(search_name, '없는 연락처 입니다.'))
        
        
    elif menu == 4:
        print('연락처를 수정합니다.')
        mod_name = input('수정할 연락처의 이름을 입력하세요: ')
              
        if mod_name in contact:
            mod_tel = input('새 전화번호를 입력하세요: ')
            contact[mod_name] = mod_tel
            print('연락처가 수정되었습니다.')
        else:
            print('연락처를 찾을 수 없습니다.')
        
        
    elif menu == 5:
        print('연락처를 삭제합니다.') 
        delete_name = input('삭제할 연락처의 이름을 입력하세요: ')
        if delete_name in contact:
            del contact[delete_name]
            print('연락처가 삭제되었습니다.')
        else:
            print('연락처를 찾을 수 없습니다.')
        
        
    elif menu == 6:
        print('프로그램을 종료 합니다.')
        break
        
    else:
        print('잘못된 입력입니다. 다시 입력해 주세요.')

# %%
## 강사님 코드

contact = {}

while True:
    print('------ 전화번호부 프로그램 ------')
    print('1.추가   2.보기    3.검색   4.수정   5.삭제    9.종료')

    menu = int(input('메뉴를 선택해주세요(숫자 only)'))

    if menu == 1:
        print('연락처를 추가합니다.')
        new_name = input('이름 : ')
        new_tel = input('전화번호 : ')
        print(new_name, new_tel)
        # contact[new_name] = new_tel # 덮어쓰기
        contact.setdefault(new_name, new_tel)

    elif menu == 2:
        print('연락처를 조회합니다.')
        # print(contact)
        # print('='*10)
        for name, tel in contact.items():
            print(name, ":", tel)

    elif menu == 3:
        print('연락처를 검색합니다.')
        search_name = input('검색 이름: ')
        # print(contact[search_name])
        print(contact.get(search_name, '없는 연락처입니다.'))

    elif menu == 4:
        print('연락처를 수정합니다.')
        mod_name = input('수정 이름 : ') # 연락처에 있을 경우에만 새전화번호를 묻는 것이.
        if mod_name in contact:
            mod_tel = input('새 전화번호 : ')
            contact[mod_name] = mod_tel
        else :
            print('등록되지 않은 이름입니다.')

    elif menu == 5:
        print('연락처를 삭제합니다.')
        del_name = input('삭제 이름 : ')
        if del_name in contact:
            del contact[del_name]
        else :
            print('등록되지 않은 이름입니다.')

    elif menu == 9:
        print('프로그램을 종료합니다.') 
        break

    else :
        print('잘못된 입력입니다.')
